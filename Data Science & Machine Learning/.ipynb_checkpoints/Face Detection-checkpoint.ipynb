# %%
import numpy as np
from PIL import Image
from mtcnn.mtcnn import MTCNN
from keras_vggface.vggface import VGGFace
from keras_vggface.utils import preprocess_input

# %%
import tensorflow as tf

# %%
print(tf.__version__)
# Out:
# 2.17.0

# %%
D = MTCNN()

# %%
model = VGGFace(model='resnet50',include_top=False,input_shape=(224,224,3),pooling='avg')
# Out:
# ...
# 94694792/94694792 ━━━━━━━━━━━━━━━━━━━━ 11s 0us/step

# %%
P1 = Image.open(r"C:\Users\Sub\CodeSpace\AI\mastering_convolutional_neural_networks\Data\FaceVerification\pos_1.jpg")
P2 = Image.open(r"C:\Users\Sub\CodeSpace\AI\mastering_convolutional_neural_networks\Data\FaceVerification\pos_2.jpg")
N = Image.open(r"C:\Users\Sub\CodeSpace\AI\mastering_convolutional_neural_networks\Data\FaceVerification\neg_1.jpg")

# %%
N
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=250x250>

# %%
# convert all image asarray
P1 =  np.asarray(P1)
P2 = np.asarray(P2)
N = np.asarray(N)

# %%
def f_getface(I):
    r = D.detect_faces(I)
    x1,y1,w,h = r[0]['box']
    x2,y2 = x1+w,y1+h
    face = I[y1:y2,x1:x2]
    return Image.fromarray(face)

# %%
f1 = f_getface(P1)
f2 = f_getface(P2)
f3 = f_getface(N)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# ...

# %%
f1
# Out:
# <PIL.Image.Image image mode=RGB size=96x123>

# %%
f2
# Out:
# <PIL.Image.Image image mode=RGB size=97x126>

# %%
f3
# Out:
# <PIL.Image.Image image mode=RGB size=95x130>

# %%
# resize the images
f1 = f1.resize((224,224))
f2 = f2.resize((224,224))
f3 = f3.resize((224,224))

# %%
f1 = np.asarray(f1,'float32')
f2 = np.asarray(f2,'float32')
f3 = np.asarray(f3,'float32')

# %%
f1 = process
